# %% [markdown]
# Based on [Ksamsok-basics](https://gist.github.com/Abbe98/882a374350d20b980190c3148f787f5a) see also [Abbe98/awesome-k-samsok](https://github.com/Abbe98/awesome-k-samsok)
#
# * this [Notebook](https://github.com/perrohdin/Bildhistoria-Masterdata-och-Wikidata/blob/main/Notebook/Ksamsok-skola.ipynb)

# %%
from datetime import datetime
start_time  = datetime.now()
print("Last run: ", start_time)
# Out:
# Last run:  2022-06-09 09:30:30.484994

# %%
import math
import requests

# %%
# K-samsök supports JOSN if given the following Accept header
headers = {
    'Accept': 'application/json'
}

# We will work with two of K-samsöks methods search/fields for getting data
# and statisticSearch for automatic statistics
endpoint = 'http://www.kulturarvsdata.se/ksamsok/api'
endpoint_fields = '{}?&x-api=test&method=search&hitsPerPage=500&recordSchema=xml'.format(endpoint)
endpoint_facet = '{}?&x-api=test&method=statisticSearch&removeBelow=1'.format(endpoint)

# %%
# K-samsök uses the query language CQL
# it allows you to create very advanced queries
# https://www.loc.gov/standards/sru/cql/
    
# K-samsök has a lot of fields that you can query:
# https://www.raa.se/hitta-information/k-samsok/att-anvanda-k-samsok/index-for-statistic-facet/
# https://www.raa.se/hitta-information/k-samsok/att-anvanda-k-samsok/ytterligare-index-for-sok/
    
# Ask K-samsök for photos with type folkskola
query = 'itemType=foto AND thumbnailExists=j AND itemMotiveWord=skola'
#query = 'itemType=foto AND thumbnailExists=j AND create_fromTime<=1890'
# Lets also specify which fields we want to recive
fields = 'itemLabel,itemDescription,create_fromTime,thumbnail,itemMotiveWord,copyright'

# the following is a generator
# a generator is similar to a function
# but insead of returning something once
# it returns mulityply things which you can loop over
# this particular generator uses K-samsöks methods search/fields to recive data
# you can resuse this generator in you own projects
def search_field_generator(query, fields):
    # initial query to know how many results we get
    query_url = '{}&query={}&fields={}&startRecord='.format(endpoint_fields, query, fields)
    r = requests.get(query_url, headers=headers)
    json = r.json()

    # K-samsök only returns 500 results in a single request
    # therefor we need to use the total number of results
    # to calculate the number of request we could potentially need to do
    total_results = json['result']['totalHits']
    required_n_requests = math.ceil(total_results / 500)

    # now we can start querying while keeping track of where in the results we are
    count = 0
    while required_n_requests > count:
        start_record = count * 500
        count += 1

        r = requests.get(query_url + str(start_record), headers=headers)
        response_data = r.json()

        for record in response_data['result']['records']['record']:
            # sometimes there are empty records and those has no fields :-(
            if not len(record) == 2:
                continue
                
            item_to_yield = {}
            
            # some fields can appear multiply times
            # therefor we need to merge those to lists if needed
            for field in record['field']:
                # if the field is already a list 
                if isinstance(item_to_yield.get(field['name'], False), list):
                    item_to_yield[field['name']].append(field['content'])
                # if it's not yet a list but we found the same field name/key again
                elif item_to_yield.get(field['name'], False):
                    item_to_yield[field['name']] = list([item_to_yield[field['name']], field['content']])
                # default to just a regular value
                else:
                    item_to_yield[field['name']] = field['content']

            yield item_to_yield

# %%
import pandas as pd
dfTot = pd.DataFrame()
# now we can loop our generator and print all the results
for record in search_field_generator(query, fields):
    print(record)
    #dfTot = pd.concat([dfTot,pd.DataFrame(record)])
# you can change the values of query and fields get the data you need
# Out:
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/271977', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 'Fotografi av Praktiska Realskolan (Clemensskolan) med fresk av Erik Cederberg', 344, 'arkitektur', 532], 'create_fromTime': 1965, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/296379/65_346.jpg', 'itemMotiveWord': ['Praktiska realskolan', 'Fresk av Erik Cederberg', 'skola', 'interiörer', 'byggnad', 'Clemensskolan', 'smide']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/621473', 'itemLabel': 'fotografi', 'itemDescription': ['BI-OMRÅDET FREDRIKSDAL, DROTTNINGHÖG, DALHEM [på diaboxen]', 'Dalhem', 'Under 2013 utförde Kulturmagasinet dokumentation av bostadsområdet Drottninghög. Det gjordes intervjuer, fotodokumentation och insamling av fotografier och i viss mån, föremål.\n\nBilden lånades från Titti Möllerstedt och skannades. Bilderna kom ursprungligen från Drottninghögs fritidsgård och togs om hand av TM när fritidsgården lades ner 1995.', 'Foto', 'inlånat och scannat', 361], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/637380/DIG_2013_825.jpg', 'itemMotiveWord': ['bostadshus', 'skola', 'arkitektur, i staden', 'bostadsområde', 'Dalhem']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/807072', 'itemLabel': 'vykort, fotografi', 'itemDescription': [341, 'inlånat och scannat', 346, 'Vykort med svartvitt fotografi föreställande Vanföresanstaltens skolhem i Raus Planteringen. Skolhemmet byggdes klart 1918 och var till funktionshindrande barn och ungdomar.', 87, 'Foto', 'HÄLSINGBORG. Vanföreanstaltens skolhem. [framsidan]'], 'create_fromTime': 1920, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/809938/DIG_2009_017.jpg', 'itemMotiveWord': ['arkitektur, på landet', 'byggnad', 'Berzeliusgatan', 'Vanföreanstalten', 'arkitektur', 'skola', 'träd', 'Planteringen', 'Grynet']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/620800', 'itemLabel': 'fotografi', 'itemDescription': ['Under 2013 utförde Kulturmagasinet dokumentation av bostadsområdet Drottninghög. Det gjordes intervjuer, fotodokumentation och insamling av fotografier och i viss mån, föremål.\n\nBilden lånades från Titti Möllerstedt och skannades. Bilderna kom ursprungligen från Drottninghögs fritidsgård och togs om hand av TM när fritidsgården lades ner 1995.', 'Musikframträdande av och för ungdomar i Fredriksdalsskolans matsal.', 'Div. kort gården 89-90  [på diaboxen]', 883, 'Kvällen anordnades av nätverket "Distrikt B". I distriktet ingick socialtjänsten, polis och skola för områdena Dalhem, Drottninghög och Fredriksdal. Man anordnande olika evenemang som involverade alla. Varje disktrikt hade en egen logga och Disktrikt B hade ett B i ett spindelnät.', 345, 'inlånat och scannat', 'Foto'], 'create_fromTime': 1989, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/641928/DIG_2013_801.jpg', 'itemMotiveWord': ['fågel', 'skola', 'musikutövning', 'Fredriksdal', 'ungdom', 'Fredriksdalsskolan', 'scener, övriga']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/282996', 'itemLabel': 'fotografi', 'itemDescription': ['Bild som visar en skolklass på Nya Elemantarskolan, skolan hette sedan Gossläroverket och till slut Nicolaiskolan. detta är ett gruppporträtt av klass L 6:2 1905 eller 1906.', 'monterad på kartong', 873, 875, 346, 'Foto'], 'create_fromTime': 1906, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/323769/211_41_012.jpg', 'itemMotiveWord': ['Åkesson, Nils lektor [nedre raden förste från vänster]', 'Maré, Rolf de [andra raden sjunde från vänster]', 'Bjerstedt, Erik [andra raden femte från vänster]', 'Hellners, Eggert [nedre raden andre från vänster]', 'Jensson [översta raden tredje från vänster]', 'Andersson, Anders Helsingborg [nedre raden sjätte från vänster]', 'Olsson-Möller, Olle [andra raden tredje från vänster]', 'Bengtsson, Lars-Gunnar [översta raden fjärde från vänster]', 'Olsson, Sture [översta raden andre från vänster]', 'Wahlgren, Bror [andra raden andre från vänster]', 'Helgesson, Eskil [nedre raden femte från vänster]', 'Thorn, Emil [nedre raden tredje från vänster]', 'grupporträtt', 'Kvist, Helge [nedre raden fjärde från vänster]', 'rektor', 'skola', 'Nilsson, Otto Helsingborg [andra raden fjärde från vänsre]', 'Resen, Gunnar [översta raden förste från vänster]', 'Widmark, Erik [andra raden sjätte från vänster]', 'Strömberg, Nils [nedre raden sjunde från vänster]', 'skolklass', 'Sommelius, Allan [översta raden femte från vänster]', 'Jacobsson, Ragnar [andra raden förste från vänster]']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/271916', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 873, 347, 'Provskrivning i Praktiska realskolans aula.', 'arkitektur'], 'create_fromTime': 1962, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/296786/62_502.jpg', 'itemMotiveWord': ['Praktiska realskolan', 'Munkavägen', 'Lampan', 'Snäckan 1', 'skolundervisning', 'skola', 'interiörer', 'byggnad']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/1766170', 'itemLabel': 'fotografi', 'itemDescription': ['År 1863 uppfördes det s.k. Gamla läroverket (sedermera Handelsgymnasiet), (https://stadslexikon.helsingborg.se/?s=handelsgymnasium)', 346, 'gåva', 'I förgrunden ytor med buskar, mitt i bild anar manen väg och i bakgrunden ligger en skolbyggnad med två våningar.', 367, 'Bilder använda i bevarandeprogram för stadskärnan 1985. Fotograferade 1980 och 1985.', 'Uppfördes som läroverksbyggnad 1862-63. Som arkitekt anlitades Helgo Zetterwall, som då var verksam i Lund och något år senare fick i uppdrag att rita Helsingborgs Centralstation.\r\nBygganden är i två vångar och försedd med kraftigt farmskjutande sidopartier. Även mittpartiet är framhävt. Fasaden är putsad och målad.', 341, 'Foto', 'Helsingborgs stadskärna Bevaringsprogram 1985'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1780229/80_231_04.jpg', 'itemMotiveWord': ['skola', 'Gamla Läroverket', 'Minerva 24', 'arkitektur, i staden', 'byggnad', 'väg', 'Bergaliden 9', 'park']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/246642', 'itemLabel': 'vykort, fotografi', 'itemDescription': [312, 885, 344, 'Foto', 346, 'Utsikt från Kärnan över S:t Petri vattentorn och Slottsvångsskolan. Överst på kortet står texten: "Helsingborg rundt No. 1."', 367], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/314386/1749_2002.jpg', 'itemMotiveWord': ['skola', 'Barnsjukhuset', 'landskap', 'Slottsvångsskolan', 'kvinna', 'sjukhus', 'man', 'S:t Petri Vattentorn', 'vattentorn', 'park']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/1744269', 'itemLabel': 'fotografi', 'itemDescription': ['I förgrunden skolgård, sedan tvåvåningsbyggnad med vind. Framför byggnaden ett träd. Raus Planterings skola innan rivning', 'gåva', 346], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1767621/6672-2021.jpg', 'itemMotiveWord': ['skola', 'Raus Planterings skola', 'arkitektur, i staden', 'träd', 'skolgård', 'byggnad']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/620798', 'itemLabel': 'fotografi', 'itemDescription': [883, 'Kvällen anordnades av nätverket "Distrikt B". I distriktet ingick socialtjänsten, polis och skola för områdena Dalhem, Drottninghög och Fredriksdal. Man anordnande olika evenemang som involverade alla. Varje disktrikt hade en egen logga och Disktrikt B hade ett B i ett spindelnät.', 'Div. kort gården 89-90  [på diaboxen]', 345, 'Gruppen NOVA spelar för ungdomar i Fredriksdalsskolans matsal.', 'Under 2013 utförde Kulturmagasinet dokumentation av bostadsområdet Drottninghög. Det gjordes intervjuer, fotodokumentation och insamling av fotografier och i viss mån, föremål.\n\nBilden lånades från Titti Möllerstedt och skannades. Bilderna kom ursprungligen från Drottninghögs fritidsgård och togs om hand av TM när fritidsgården lades ner 1995.', 'Foto', 'inlånat och scannat'], 'create_fromTime': 1989, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/641924/DIG_2013_800.jpg', 'itemMotiveWord': ['ungdom', 'Fredriksdal', 'Saldert, Jörgen [keyboard]', 'skola', 'Fredriksdalsskolan', 'musikutövning', 'scener, övriga', 'Olausson, Håkan [gitarrist]']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/238048', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 346, 345, 'Slottshagen med tennishallen och Nicolaiskolan i bakgrunden', 367], 'create_fromTime': 1905, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/252384/00_303.jpg', 'itemMotiveWord': ['Minerva', 'skola', 'Nicolaiskolan', 'Tennishallen', 'park', 'sportanläggning', 'landskap']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/253021', 'itemLabel': 'fotografi', 'itemDescription': [871, 'ur äldre samling', 668, 346, 'Magnus Stenbocksskolan, från början kallad Nya Skolan respektive Tågaborgsskolan, på 1910-talet. Uppfördes under Stenbocksjubileets år 1910 (vilket firades med bl a militärparader, tacksägelsegudstjänster och allmän flaggning), och är belägen på de höjder som på närmare håll haft känning av  "den minnesrika tilldragelse som är förknippad med den store fältherrens namn" (det vill säga slaget vid Helsingborg) som Arvid Gierow skriver i "Hälsingborgs barndomsskola genom tiderna : Till hundraårsminnet : På folkskolsytrelsens uppdrag tecknad" från 1938.  Magnus Stenbocksskolan blev sedan högstadieskola. Är nu ombyggd till bostäder.', 'Foto', 344, 872, 186], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/312027/1173_2002.jpg', 'itemMotiveWord': ['Tågaborgsskolan', 'Magnus Stenbocksskolan', 'skola', 'folkskola', 'Nya Skolan', 'byggnad']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/326487', 'itemLabel': 'fotografi', 'itemDescription': [361, 346, 'Västkustvägen 44, huset var tidigare var småskola i Lyckåker (Hasslarps tidigare bynamn). Namnet på fasaden är bland de få kvarvarande tecknen på det tidigare ortsnamnet.', 'Foto', 362], 'create_fromTime': 1991, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/343929/91_315.jpg', 'itemMotiveWord': ['byggnad', 'trädgård', 'skola', 'arkitektur, på landet', 'bybebyggelse', 'bil']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/249674', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 'ur äldre samling', 346, 342, 'Bostadshus på söder med Gustavadofsskolan i bakgrunden.'], 'create_fromTime': 1941, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/311350/898_2002.jpg', 'itemMotiveWord': ['bostadsområde', 'byggnad', 'Gustav Adolfsskolan', 'skola', 'bostadshus']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/405381', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 'Utanför montessoriförskolan Montemini på Maria Park.', 'I samband medatt museet gjorde en insamling av berättelser av barn vars föräldrar arbetat på Sankta Maria och därför bott på området, kom vi i kontakt med Bengt Öster.\nNär han besökte Kulturmagasinet för att låna ut fotografier erbjöd han sig att guida oss på Sankta Maria .\n\nDen 24 augusti 2006 körde personal från museet upp till Mariastaden för att träffa honom. Lena Wilhelmsson tog bilder och antikvarierna Therese Kruse och Birgitta Witting nedtecknade Bengts berättelse (se arkiv).\n\nMaria Park är namnet på ett före detta sjukhusområde i stadsdelen Mariastaden i norra Helsingborg. Sjukhuset hette förr Sankta Maria sjukhus och fungerade som mentalsjukhus från invigningen 1927 till 1990-talet då sjukhuset avvecklades. Samtidigt med avvecklingen bytte området namn till Maria Park och byggnaderna innehåller nu bostäder, kontorslokaler och ett antal skolor. Här finns också ett par kommunala förvaltningar, liksom Skånes Näringslivsarkiv.', 346], 'create_fromTime': 2006, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/407359/DIG_2009_223.jpg', 'itemMotiveWord': ['Montemini', 'skola', 'Östra Allén', 'skolrast', 'arkitektur, i staden', 'barn', 'träd', 'Mariastaden', 'gunga']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/424009', 'itemLabel': 'fotografi', 'itemDescription': ['lånat och scannat', 'Foto', 346, 87, 'Gantofta nya skola'], 'create_fromTime': 1965, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/424017/DIG_2011_1302.jpg', 'itemMotiveWord': ['arkitektur, på landet', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/318220', 'itemLabel': 'fotografi', 'itemDescription': ['Bild från när de tömde Gustav Adolfskolan 30/9 2004. I samband med att föremål förvärvades visades vi runt av biträdande rektor AnnMargret Wendt. Modellen på bilden gjordes av elever till skolans 100-årsjubileum. Den togs in i museets samlingar och har inv.nr. 808-2004.', 'Foto', 'inlånat och scannat', 211, 346, 'Gustav Adolf skolan lades ner 2004 efter våldsamma protester. Föremål och artiklar samlades in.'], 'create_fromTime': 2004, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/321241/DIG_2004_904.jpg', 'itemMotiveWord': ['interiörer', 'modell', 'skola', 'Gustav Adolfsskolan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/272676', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 'Bild av Köpinge skola.', 346, 351, 'arkitektur'], 'create_fromTime': 1967, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/293232/67_387.jpg', 'itemMotiveWord': ['skola', 'träd', 'staket', 'Runstenen', 'Brunnsvägen']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/1813526', 'itemLabel': 'fotografi', 'itemDescription': [86, 'gåva', 861, 872, 211, 856, 21, 85, 'Fotografiet är del av en samling kläder, föremål och fotografier givna till Helsingborgs Museum av Siv Liljeqvist, hösten 2021. Som barn drabbades Siv av polio, vilket speciellt kom att påverka hennes högra ben. Trots sin diagnos bestämde sig Siv tidigt, redan i realskolan, för att bli sömmerska och textillärare. Siv antogs till sömnadsutbildningen vid Vanföreantaltens Yrkesskola i Helsingborg 1953 och fick därefter sin gesällutnämning 1956. Flertalet av de plagg som Siv skänkt till museet har hon sytt själv.', 'Foto', '370-2022', 855, 'Svartvitt fotografi från november 1984. Bilden föreställer Per Ola Liljeqvist (f. 1976) som sitter vid en skolbänk och skriver. Per Ola bär en randig tröja (se objekt med inv.nr. 370-2022). Fotografiet är taget på Bäckaskolan i Viken, av Einar Liljeqvist, pappa till Per Ola.', '7-11-84 Bäckaskolan, Viken Foto: Einar Liljeqvist [baksida]', '361--388-2022', 87, 215], 'create_fromTime': 1984, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1816596/363-2022_001.jpg', 'itemMotiveWord': ['tröja', 'klassrum', 'gardin', 'skola', 'Liljeqvist, Per Ola', 'barn', 'fönster', 'pojke', 'undervisning', 'Bäckaskolan', 'vardagsliv', 'Liljeqvist, Siv', 'skolelev', 'skolbänk', 'penna']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/576538', 'itemLabel': 'vykort', 'itemDescription': ['Slottvångsskolan', 'ur äldre samling', 'Foto', 361, 'Nilssons ljustrycksanstalt, Stockholm 10258'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/576549/5423-2013.jpg', 'itemMotiveWord': ['Slottsvångsskolan', 'arkitektur, i staden', 'skola', 'park']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/370664', 'itemLabel': 'fotografi', 'itemDescription': ['gåva', 365, 'Lindberg Foto', 87, 'Fotografi av en skolklass, möjligen är Olle Lindberg (f.1907) en av eleverna.', 346, 'Foto', 85], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/370667/908-2007.jpg', 'itemMotiveWord': ['skolklass', 'barn', 'skola', 'skolelev']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/369823', 'itemLabel': 'vykort', 'itemDescription': ['Foto', 361, 'Vykort föreställande Gustaf Adolfs skolan, när skolan just färdigställts.', 'Skolan uppfördes 1898-1900.', 311, 'inlånat och scannat', 87, 346], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/369826/DIG_2007_344.jpg', 'itemMotiveWord': ['stadsbebyggelse', 'offentlig byggnad', 'skola', 'arkitektur, i staden', 'bebyggelse', 'Gustav Adolfsskolan', 'Gustav Adolf', 'fasadutformning', 'Eneborg']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/283367', 'itemLabel': 'fotografi', 'itemDescription': [346, 885, 524, 'Foto', 'Bild av en lek som heter " slå katten ur tunnan " vid Tekniska högskolan som låg vid sidan om gossläroverket, mycket folk som ser på.', 'scener'], 'create_fromTime': 1922, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/315158/22_135.jpg', 'itemMotiveWord': ['skola', 'barn', 'lek', 'man', 'kvinna', 'tunna']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/576458', 'itemLabel': 'fotografi', 'itemDescription': ['Under 2013 utförde Kulturmagasinet dokumentation av bostadsområdet Drottninghög. Det gjordes intervjuer, fotodokumentation och insamling av fotografier och i viss mån, föremål.', 'Helsingborgs Dagblad 2014-09-14 [publicerat i]', 361, 'Röster från Drottninghög, Klintmans hörna 9/9 2014 - [Gemenskap, vägg 3 + 4]', 'Bilden visar gångvägen mellan Rödkulla och Drottninghögsskolan. Gångvägen är kantad av träd och människor promenerar på den.', 87, 'Foto'], 'create_fromTime': 2013, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/584860/DIG_2013_395.jpg', 'itemMotiveWord': ['träd', 'arkitektur, i staden', 'Drottninghögsskolan', 'Drottninghög', 'Rödkullagatan', 'bostadshus', 'bostadsområde', 'allé', 'skola', 'barnvagn', 'Drottninghög N:A']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/1710217', 'itemLabel': 'fotografi, kontaktkarta, avfoto', 'itemDescription': ['För ytterligare information om negativen kan man titta på negativbladen på Kulturmagasinet, många av negativbladen har beskrivningar av vad negativen avbildar. Se även Signering, påskrift, stämpling.', 'Fotografi', 'Fotografier som avbildar städer, landskap och folk i Sverige och bortom av Ralph Nykvist under hans många färder.', '25/2 Hemma hos Christina pastor, Cecilia Nash, Jörgen Nash, Malmö Central, Huset i Köpenhamn, 26/2 Monica 11-78, Felor. Fäladsgården, Eva & Janet 12-78 [Skrivet på negativbladet, datum, filmrulle-år]', '34 stycken bilder som avbildar vardagsscener, platser och personer. Här avbildas Christina Pastors hem på bild 2-11. Cecilia Nash på bild 6-8. Jörgen Nash på bild 9-10. Malmö Central på bild 12-14. "Huset i Köpenhamn" på bild 15-25. Monica på bild 26-28. Fäladsgården grundskola i Lund på bild 11-14. Och Eva och Janet på bild 15-16.', 'Ralph Nykvist', 'gåva'], 'create_fromTime': 1978, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1710420/1243-2021.jpg', 'itemMotiveWord': ['övergångsställe', 'fönster', 'telefonkiosk', 'rökning', 'kvinnoporträtt', 'högtalare', 'tidning', 'mansporträtt', 'gardin', 'lampa', 'telefonapparat', 'väggmålning', 'exteriör', 'flaska', 'pall', 'interiörer', 'restaurang', 'kanna', 'ljus', 'skola', 'mansklädsel', 'dörr', 'gunga', 'bord', 'cigarett', 'cykel', 'kvinnoklädsel', 'barnporträtt', 'element', 'kopp', 'telefon', 'katt', 'stol', 'växt', 'tågstation', 'pingisbord', 'burk', 'barnklädsel']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/835246', 'itemLabel': 'fotografi', 'itemDescription': [346, 875, 'gåva', 'Svartvit grupporträtt av elever och lärare som står uppradade  på gårdsplanen till fotografering vid Gossläroverket i Helsingborg.', 'Foto'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/912365/479_51_37.jpg', 'itemMotiveWord': ['Gossläroverket', 'skolklass', 'skola', 'grupporträtt', 'lärare']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/252925', 'itemLabel': 'fotografi', 'itemDescription': [346, 'Foto', 'Råå norra folkskola. Någon har skrivit under fotot med bläck: "Gick i skola här 1884-89." Fotografens namn står skriven med blyerts: "??? Möl???" (oläsligt) samt årtalet 1942. Avfoto maj 1974.', 'ur äldre samling', 87], 'create_fromTime': 1942, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/312151/1221_2002.jpg', 'itemMotiveWord': ['byggnad', 'Råå norra skola', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/281554', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 872, 346, 'Bild av Köpinge skolas gymnastiksal.'], 'create_fromTime': 1967, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/316649/67_394.jpg', 'itemMotiveWord': ['skola', 'Brunnsvägen', 'interiörer', 'gymnastiksal']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/249701', 'itemLabel': 'fotografi', 'itemDescription': [363, 133, 346, 'Foto', 'ur äldre samling', 'Flygbild över Drottninggatan och Pålsjö vid Villa Thalassa. På papprat står skrivet: "Flygfoto Oscar Bladh AB, Bromma, n:r H 2-1584."', 241, 342], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/311341/895_2002.jpg', 'itemMotiveWord': ['Riggen', 'byggnad', 'Rodret', 'odlingslandskap', 'stadsgata', 'Tåget norra', 'bostadshus', 'väg', 'strand', 'åkermark', 'Villa Thalassa', 'skola', 'Pålsjö skola', 'Drottninggatan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/275076', 'itemLabel': 'fotografi', 'itemDescription': [346, 'fotografi, av Preben Jacobsson framför griffeltavla', 'gåva', 'Foto', 885], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/278850/511_2004.jpg', 'itemMotiveWord': ['skola', 'man', 'interiör', 'Jacobsson, Preben', 'lärare', 'skolsal', 'mansporträtt']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/277075', 'itemLabel': 'fotografi', 'itemDescription': ['inlånat och scannat', 346, 264, 'Foto', 'Grupporträtt av Oscar Olssons skolklass på Slottsvångsskolan. Själv sitter han sannolikt längst till vänster andra raden.', 855, 875], 'create_fromTime': 1910, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/321281/DIG_2005_291.jpg', 'itemMotiveWord': ['skola', 'skolklass', 'Slottsvångsskolan', 'lärare', 'Olsson, Oscar f.1903', 'barn', 'klädsel', 'grupporträtt']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/318231', 'itemLabel': 'fotografi', 'itemDescription': ['Bild från när de tömde Gustav Adolfskolan 30/9 2004. I samband med att föremål förvärvades visades vi runt av biträdande rektor AnnMargret Wendt. Bilden visar hur man river ut ett alldeles nytt hemkunskapskök.', 'Foto', 346, 872, 'Gustav Adolf skolan lades ner 2004 efter våldsamma protester. Föremål och artiklar samlades in.', 'inlånat och scannat'], 'create_fromTime': 2004, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/321244/DIG_2004_905.jpg', 'itemMotiveWord': ['Gustav Adolfsskolan', 'kök', 'skolsal', 'skola', 'interiörer']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/628565', 'itemLabel': 'fotografi', 'itemDescription': [883, 'Ungdomar i rökrutan på Fredriksdalsskolans skolgård.', 346, 'Rökruta är en för tobaksrökning avsedd del av en skolgård. Rökrutor förekom i Sverige främst på grundskolans tidigare högstadium samt i gymnasieskolan. Den 1 juli 1994 förbjöds rökrutorna i Sveriges skolor, men vissa skolor hade redan tidigare avskaffat dem.', 'Foto', 'inlånat och scannat', 'Under 2013 utförde Kulturmagasinet dokumentation av bostadsområdet Drottninghög. Det gjordes intervjuer, fotodokumentation och insamling av fotografier och i viss mån, föremål.\n\nBilden lånades från Titti Möllerstedt och skannades. Bilderna kom ursprungligen från Drottninghögs fritidsgård och togs om hand av TM när fritidsgården lades ner 1995.', 276], 'create_fromTime': 1976, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/637941/DIG_2013_968.jpg', 'itemMotiveWord': ['skola', 'scener, övriga', 'tobaksbruk', 'Albertsson, Eva [mitten]', 'Fredriksdalsskolan', 'Helin, Karin [t.v.]', 'Fredriksdal', 'Kvist, Suzi [t.h.]', 'ungdom']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/732015', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 'Nils-Åke Siversson', 'Utsikt från Kärnans topp, Österut.', 'Siversson, Nils-Åke', 'inköp', 361], 'create_fromTime': 1984, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/732025/53-2014.jpg', 'itemMotiveWord': ['bebyggelse', 'stadsbebyggelse', 'park', 'Slottsvångsskolan', 'skola', 'arkitektur, i staden', 'Slottshöjden']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/297067', 'itemLabel': 'fotografi', 'itemDescription': [186, 346, 'Svartvit fotografi. Magnus Stenbocksskolan i Helsingborg.', 'Foto'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/299073/AB831.jpg', 'itemMotiveWord': ['arkitektur, i staden', 'Magnus Stenbocksskolan', 'skola', 'flaggstång']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/265995', 'itemLabel': 'fotografi', 'itemDescription': [346, 872, 'Nicolaiskolan i Helsingborg. I nedre högra hörnet står signaturen: "G.&E".', 'Foto'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/312603/1835_2002.jpg', 'itemMotiveWord': ['Gossläroverket', 'byggnad', 'skola', 'Minerva', 'Högre Allmänna läroverket', 'Nicolaiskolan', 'Elementarläroverket']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/272663', 'itemLabel': 'fotografi, vykort', 'itemDescription': [363, 346, 'Foto', 344, 351, 'Bergaliden i krönet vid Nicolaiskolan och Handelsgymnasiet, en spårvagn på väg ner för backen.'], 'create_fromTime': 1905, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/324607/634_2004.jpg', 'itemMotiveWord': ['offentlig byggnad', 'staket', 'spårvagn', 'skola', 'arkitektur, i staden', 'Handelsgymnasiet', 'stadsgata', 'Minerva', 'Bergaliden', 'Nicolaiskolan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/329374', 'itemLabel': 'vykort, fotografi', 'itemDescription': [351, 85, 'fotografi föreställande Gossläroverket   1898', 'Ur disponent W. Anderssons samling', 883, 346, 'Foto'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/366829/43_2006_002.jpg', 'itemMotiveWord': ['arkitektur, i staden', 'Gossläroverket', 'gårdsplan', 'skola', 'pojke', 'flicka']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/626336', 'itemLabel': 'fotografi', 'itemDescription': ['En kvinna har hämtat och en grupp barn på Drottninghögsskolans skolgård. De skall till "Fritidsklubben" efter skolan.', 'inlånat och scannat', 885, 85, 'Under 2013 utförde Kulturmagasinet dokumentation av bostadsområdet Drottninghög. Det gjordes intervjuer, fotodokumentation och insamling av fotografier och i viss mån, föremål.\n\nBilden lånades från Titti Möllerstedt och skannades. Bilderna kom ursprungligen från Drottninghögs fritidsgård och togs om hand av TM när fritidsgården lades ner 1995.', 346, 'Bilden är från "Fritidsklubben"! Med statliga medel så fick man starta fritidsklubbar för de barn som inte längre fick en plats på dagis och fritidshem när de började i årskurs 3. Den mörkhåriga kvinnan på bilderna var en praktikant, de som ledde gruppen hette Maria Hermansson och Sigfrid Fredestad. När sedan verksamheten var igång så jobbade även övriga fritidsledare med fritidsklubbs barnen.\n\nFritidsklubben var inrymd i Drottninghögs fritidsgårds lokaler.', 'Foto'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/637648/DIG_2013_902.jpg', 'itemMotiveWord': ['kvinna', 'skola', 'scener, övriga', 'barn', 'Drottninghög']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/283360', 'itemLabel': 'fotografi', 'itemDescription': ['Bild av en lek som heter " slå katten ur tunnan " vid Tekniska högskolan som låg vid sidan om gossläroverket, mycket folk som ser på.', 885, 524, 346, 'Foto', 'scener'], 'create_fromTime': 1922, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/315149/22_132.jpg', 'itemMotiveWord': ['tunna', 'skola', 'lek', 'man', 'kvinna']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/576515', 'itemLabel': 'vykort', 'itemDescription': ['Imp. No.349, Kilbergs bokhandel', 'Foto', 361, 'Slottvångsskolan', 'ur äldre samling'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/576530/5422-2013.jpg', 'itemMotiveWord': ['arkitektur, i staden', 'skola', 'Slottsvångsskolan', 'park']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/271983', 'itemLabel': 'fotografi', 'itemDescription': ['arkitektur', 344, 'Fotografi av Arbetsvårdsverkstaden med trappdekor av Tormod Larsen', 532, 'Foto'], 'create_fromTime': 1965, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/298643/65_355.jpg', 'itemMotiveWord': ['interiörer', 'konstverk', 'skola', 'Arbetsvårdsverkstaden', 'byggnad', 'Trappdekor av Tormod Larsen']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/249324', 'itemLabel': 'fotografi', 'itemDescription': [346, 'Foto', 344, 872, 'ur äldre samling', 'Margaretaskolan, Kv. Turkiet i Helsingborg.'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/311649/1006_2002.jpg', 'itemMotiveWord': ['skola', 'Turkiet', 'byggnad', 'Margaretaskolan', 'folkskola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/249421', 'itemLabel': 'fotografi', 'itemDescription': ['Läroverket (gamla) sett från Gjuteriet i Helsingborg.', 'Foto', 346, 872, 'ur äldre samling'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/311572/987_2002.jpg', 'itemMotiveWord': ['Kristerssons (grundskola) (2003)', 'Handelsgymnasiet', 'skola', 'byggnad', 'Helsingborgs högre handelsinstitut och Tekniska Yrkesskolan (1904)', 'Läroverket (1891) [Gamla]']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/820030', 'itemLabel': 'fotografi', 'itemDescription': [346, 'fotodokumentation', 533, 534, 'Foto', 'Fotografi i färg föreställande bandet Outtrigger i Sensus studieförenings musikhus. På bilden visas Sebastian Falk(2:a vänster), Simon Peyron(3:e vänster) och Timmy Andersson(1:a vänster).', 159, 353, 885], 'create_fromTime': 2009, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/820329/DIG_2009_690.jpg', 'itemMotiveWord': ['Peyron, Simon [3:e vänster]', 'skola', 'musiker', 'Sensus Studieförbund Musikhuset', 'Andersson, Timmy [1:a vänster]', 'musikinstrument', 'interiör', 'Falk, Sebastian [2:a vänster]', 'scener, övriga', 'musikutövning', 'grupporträtt', 'man']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/315372', 'itemLabel': 'fotografi', 'itemDescription': [883, 'Textilen är sammanlagt ca. 35 meter lång och består av lösa delar. \nPå GA- skolan hade man mycket konstprojekt och gjorde sedan en samlingsutställning på KUB (denna verksamhet fann då i konserthuset) år 2001. \nTextilen gjordes av ca. 70 elever för just detta tillfälle och man klädde Konserthusets fasad med textilen. Det är en blandning av elever som har gjort textilen, från de yngsta till niorna. Först målades bakgrunden och sedan tryckta man mönster eller målade.\n\nVi har fått låna en del fotografier av Ann Margret som är tagna på hennes 60-årsdag. Hon hade då öppet hus och man klädde aulan på GA-skolan med textilen. Det var både vänner från Ekeby och barn från GA-skolan där.\nPå ena bilden syns Skrombergas socialdemokratiska kvinnoklubb (det var påsk och temat var Fågel Fenix, därav hattar med fjädrar). \nPersonerna på bilden från vänster är: Karin Nilsson, Eva Törnberg (föreståndare för fritidsgården), mannen längst bak är Sören Nilsson (arbetar på ENTEK), mannen framför är Frans Jönsson (från Ekeby), Wivi Gren (sekreterare i kvinnoklubben, skriver pjäser om Ekeby), Gull Britt Hansson, Maj Britt Jönsson (majblommekomittén), Elsi Svensson.\n\nPå den andra bilden står mestadels barn och tittar mot scenen. Den första tredjedelen mindre barn i bildens vänstra del är del av kör som sjöng under ledning av Göran Elnegård (organist i GA-församling). Damen i prickigt (svart och vitt) heter Dragica och är en mamma till barn på skolan. Bakom henne står två killar i röda tröjor. De är del av en grupp som dansade break dance. Bakom dem står en tjej och en kille. De är gamla elever. På bilden syns även en del av en arabisk danstrupp. Kvinnan längst till höger är Briten Westerlund (hemkunskapslärare).\n\nTextilen användes alltså ursprungligen på KUB och ungefär en månad senare på ovan beskrivna födelsedag. Sedan lades den undan till det var dags att lägga ner skolan, Då tog man fram den i kampen för GA. När Socialdemokraterna hade medlemsmöte på Sundspärlan stod barnen utanför och höll upp textilen som en manifestation.  Man stod också utanför Rådhuset med textilen.\nSe även 808-2004 - 810-2004\nTextilen är sammanlagt ca. 35 meter lång och består av lösa delar. \nPå GA- skolan hade man mycket konstprojekt och gjorde sedan en samlingsutställning på KUB (denna verksamhet fann då i konserthuset) år 2001. \nTextilen gjordes av ca. 70 elever för just detta tillfälle och man klädde Konserthusets fasad med textilen. Det är en blandning av elever som har gjort textilen, från de yngsta till niorna. Först målades bakgrunden och sedan tryckta man mönster eller målade.', 'inlånat och scannat', 346, 'Allt material rörande Gustav Adolfskolan är insamlat i samband med att skolan lades ner. När vi samlat in protestbanderoller och modellen av skolan kom man med den här textilen. Den var en symbol för skolan, tyckte man.', 885, 286, 'Foto', 527], 'create_fromTime': 2001, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/320486/DIG_2005_406.jpg', 'itemMotiveWord': ['väggdekoration', 'Gustav Adolfsskolan', 'Wendt, Anne Marie', 'födelsedagsfirande', 'scener, övriga', 'skola', 'textil', 'väggbeklädnad', 'födelsedagsgåva', 'ungdom', '810-2004', 'barn']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/369819', 'itemLabel': 'vykort', 'itemDescription': [87, 'inlånat och scannat', 361, 'Vykort föreställande Gustaf Adolfs skolan, när skolan just färdigställts.', 'Foto', 346, 311, 'Skolan uppfördes 1898-1900.'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/369822/DIG_2007_343.jpg', 'itemMotiveWord': ['Gustav Adolf', 'bebyggelse', 'skola', 'Eneborg', 'fasadutformning', 'Gustav Adolfsskolan', 'arkitektur, i staden', 'offentlig byggnad', 'stadsbebyggelse']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/426355', 'itemLabel': 'fotografi', 'itemDescription': [346, 'Foto', 'Gantofta småskola, Alma Bengtsson.', 'monterad på A4 ark med märkning "Helsingborgs Museum".'], 'create_fromTime': 1914, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/426358/4300-2011.jpg', 'itemMotiveWord': ['arkitektur, på landet', 'skolelev', 'skola', 'Gantofta småskola', 'skolklass']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/615525', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 'Volley bollmatch i Drottninghögsskolans gymnastiksal.', 'inlånat och scannat', 346, 526, 'Under 2013 utförde Kulturmagasinet dokumentation av bostadsområdet Drottninghög. Det gjordes intervjuer, fotodokumentation och insamling av fotografier och i viss mån, föremål.\n\nBilden lånades från Titti Möllerstedt och skannades. Bilderna kom ursprungligen från Drottninghögs fritidsgård och togs om hand av TM när fritidsgården lades ner 1995.', 'Bilder från D-hög, klotter, centrat, ungd. [på diaboxen]'], 'create_fromTime': 1976, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/641740/DIG_2013_692.jpg', 'itemMotiveWord': ['skola', 'Drottninghög', 'volley boll', 'barn', 'gymnastiksal', 'Drottninghögsskolan', 'scener, övriga']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/1726484', 'itemLabel': 'kontaktkarta, avfoto, fotografi', 'itemDescription': ['För ytterligare information om negativen kan man titta på negativbladen på Kulturmagasinet, många av negativbladen har beskrivningar av vad negativen avbildar. Se även Signering, påskrift, stämpling.', 'Ralph Nykvist', 'gåva', 'Fotografier som avbildar städer, landskap och folk i Sverige och bortom av Ralph Nykvist under hans många färder.', '35 stycken bilder som avbildar vardagsscener, platser och personer. Här avbildas olika platser i Tyskland med bland annat en tågstation, telefonkiosker och en skola med många elever.', 'Fotografi', '28/29, IX-1, 120-78 [Skrivet på negativbladet, datum, filmrulle-år]'], 'create_fromTime': 1978, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1726554/1318-2021.jpg', 'itemMotiveWord': ['hylla', 'mansporträtt', 'parrong', 'gata', 'kvinnoporträtt', 'stol', 'skåp', 'pall', 'tågvagn', 'skolelev', 'mansklädsel', 'växt', 'fönster', 'lärare', 'mur', 'byggnad', 'skolklass', 'bagagevagn', 'trottoar', 'leksak', 'skolundervisning', 'arkitektur, i staden', 'skolsal', 'skola', 'bord', 'barnporträtt', 'telefonkiosk', 'kvinnoklädsel', 'dörr', 'buss', 'kran', 'barnklädsel', 'exteriör', 'vask', 'lek', 'träd', 'telefon', 'busstation', 'tågstation', 'buske', 'bagage', 'hållplats', 'interiörer']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/271703', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 'Fotografi föreställande Slottsvångsskolan sedd från studenthemmet. Ringen som syns i förgrunden markerar det rivna vattentornet.', 346, 34, 'arkitektur'], 'create_fromTime': 1977, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/299235/77_50_10.jpg', 'itemMotiveWord': ['Magnus Erikssons gata', 'Slottsvångsskolan', 'vattentorn', 'skola', 'Bergaliden', 'Slottsvången', 'byggnad']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/820031', 'itemLabel': 'fotografi', 'itemDescription': [346, 885, 'fotodokumentation', 353, 534, 'Foto', 159, 533, 'Fotografi i färg föreställande bandet Outtrigger i Sensus studieförenings musikhus. På bilden visas Sebastian Falk(2:a vänster), Simon Peyron(3:e vänster) och Timmy Andersson(1:a vänster).'], 'create_fromTime': 2009, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/820309/DIG_2009_689.jpg', 'itemMotiveWord': ['Falk, Sebastian [2:a vänster]', 'musikutövning', 'Sensus Studieförbund Musikhuset', 'musikinstrument', 'skola', 'Andersson, Timmy [1:a vänster]', 'man', 'grupporträtt', 'Peyron, Simon [3:e vänster]', 'interiör', 'musiker', 'scener, övriga']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/423760', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 'lånat och scannat', 346, 'Gantofta skola'], 'create_fromTime': 1964, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/423763/DIG_2011_1288.jpg', 'itemMotiveWord': ['affärsverksamhet', 'kontor', 'arkitektur, på landet', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/820032', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 353, 534, 885, 346, 'Fotografi i färg föreställande bandet Outtrigger i Sensus studieförenings musikhus. På bilden visas Sebastian Falk(2:a vänster), Simon Peyron(3:e vänster) och Timmy Andersson(1:a vänster).', 159, 533, 'fotodokumentation'], 'create_fromTime': 2009, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/820299/DIG_2009_688.jpg', 'itemMotiveWord': ['Andersson, Timmy [1:a vänster]', 'man', 'grupporträtt', 'interiör', 'musiker', 'Falk, Sebastian [2:a vänster]', 'scener, övriga', 'Sensus Studieförbund Musikhuset', 'musikinstrument', 'musikutövning', 'Peyron, Simon [3:e vänster]', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/266022', 'itemLabel': 'fotografi, vykort', 'itemDescription': [186, 668, 'Foto', 871, 346, 'Magnus Stenbocksskolan, från början kallad Nya Skolan respektive Tågaborgsskolan. Överst på kortet står: "Hälsingborg. Magnus Stenbocksskolan."', 872, 344], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/312548/1826_2002.jpg', 'itemMotiveWord': ['Magnus Stenbocksskolan', 'Nya Skolan', 'folkskola', 'skola', 'Tågaborgsskolan', 'byggnad']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/266015', 'itemLabel': 'fotografi, vykort', 'itemDescription': [346, 'Kolorerat foto av Nicolaiskolan i Helsingborg. Överst på kortet står: "Hälsingborg. Läroverket."', 'Foto', 872], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/312579/1831_2002.jpg', 'itemMotiveWord': ['Elementarläroverket', 'skola', 'Nicolaiskolan', 'Högre Allmänna läroverket', 'byggnad', 'Minerva', 'Gossläroverket']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/252250', 'itemLabel': 'fotografi, flygfotografi', 'itemDescription': [346, 133, 367, 344, 349, 'ur äldre samling', 'Flygfoto över Helsingborg med Stadsparken i förgrunden.  På pappret står skrivet: "Försvarsstaben neg. nr. H 492 (Enl. tel. 2/11 -64 M. W.)"', 504, 496, 342, 'Foto'], 'create_fromTime': 1932, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/311196/744_2002.jpg', 'itemMotiveWord': ['hamn', 'byggnad', 'skola', 'stadsgata', 'rådhus', 'järnvägsstation', 'kyrka', 'hav', 'park']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/275724', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 342, 361, 'Utsikt från Rådhusets torn mot öster med Mariakyrkan som håller på att repareras, Gossläroverket(Nicolaiskolan, en hög skorsten i bakgrunden, i förgrunden Stortorget med bilar som står parkerade.Foto efter foto 1927.', 493, 346, 355, 367], 'create_fromTime': 1968, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/304838/68_918.jpg', 'itemMotiveWord': ['skola', 'park', 'torg', 'bostadshus', 'bil', 'kyrka', 'landskap', 'skorsten']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/1578047', 'itemLabel': 'fotografi', 'itemDescription': ['Fotografi som avbildar Allerums skola, tidigare Fattigvårds- och arbetsanstalten i Allerum.', 'Foto', 'DIG_2009_763—898', 'En samling fotografier och bilder som skaffades fram för att användas till böckerna Helsingborgs Historia. Alla fotografier och bilder användes inte för böckerna men många av dessa bilder har bevarats för sitt historiska värde och för motivens bevarande.', 'fotodokumentation'], 'create_fromTime': 2009, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1578393/DIG_2009_803.jpg', 'itemMotiveWord': ['träd', 'byggnad', 'skola', 'fönster', 'Skolgård', 'arkitektur, på landet', 'dörr', 'skorsten', 'lekplats']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/327085', 'itemLabel': 'fotografi', 'itemDescription': [87, 'På gränsen, 2012-04-27--, Dunkers kulturhus [digitalt utställd]', 86, 'Skolan låg i korsningen S.Hunnetorpsvägen - Vasatorpsvägen.', 'Foto', 'Skolelever i folkskolan för barn i Filborna och Östra Ramlösa. Barnen poserar i olika lekar, övervakade av lärarinnan längst till höger i bild.'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/344311/91_492.jpg', 'itemMotiveWord': ['skolklass', 'skola', 'skolundervisning', 'grupporträtt', 'byggnad', 'Andersson, Betty [längst till höger]', 'Filborna skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/272627', 'itemLabel': 'fotografi', 'itemDescription': ['arkitektur', 311, 'Foto', 'Flygfoto av Norreheds gamla skola från söder. Längs bilden framför skolan går Planteringsvägen.', 637, 346], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/299371/86_115_35_36.jpg', 'itemMotiveWord': ['Planteringsvägen', 'bostadsområde', 'Norrehedsskolan', 'skola', 'landskapsvy']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/238041', 'itemLabel': 'fotografi', 'itemDescription': ['arkitektur', 346, 349, 'Slottshagen med Slottvångsskolan och det gamla vattentornet i bakgrunden.', 369, 'Foto'], 'create_fromTime': 1905, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/252354/00_293.jpg', 'itemMotiveWord': ['park', 'Vattentornet', 'skola', 'Slottsvångsskolan', 'vattentorn', 'landskap']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/241247', 'itemLabel': 'fotografi', 'itemDescription': ['Barn framför sin skola. Privatskola på Södergatan mitt emot kyrkogården. Lärarinnan är Hanna Paulsson.', 'Foto', 87, 346], 'create_fromTime': 1893, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/284171/HeM_1658_99.jpg', 'itemMotiveWord': ['skola', 'grupporträtt', 'lärare', 'skolklass', 'Södergatan', 'Paulsson, Hanna']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/273288', 'itemLabel': 'vykort, fotografi', 'itemDescription': ['arkitektur', 'Foto', 346, 'fotografi av en skola i Buenos Aires, Argentina.', 'Fotografier från Theodor Trapp.'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/278536/474_2003_249.jpg', 'itemMotiveWord': ['skola', 'Escuela Normal de Profesores']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/249332', 'itemLabel': 'fotografi', 'itemDescription': [346, 872, 344, 'ur äldre samling', 'Foto', 'Flickläroverket (Olympiaskolan) i Helsingborg. Aulan.'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/311609/999_2002.jpg', 'itemMotiveWord': ['skolmöbel', 'Olympiaskolan', 'skola', 'byggnad', 'skolsal', 'Flickläroverket']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/265981', 'itemLabel': 'fotografi', 'itemDescription': ['Nicolaiskolan i Helsingborg', 872, 346, 'Foto'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/312660/1847_2002.jpg', 'itemMotiveWord': ['Nicolaiskolan', 'byggnad', 'Gossläroverket', 'skola', 'Minerva']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/239628', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 872, 'Fotografi av barn som står framför Syd-Östra skolan i Helsingborg.', 346], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/282938/865_49_32.jpg', 'itemMotiveWord': ['skola', 'skolklass', 'grupporträtt', 'Syd-Östra skolan', 'arkitektur, i staden']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/249329', 'itemLabel': 'fotografi', 'itemDescription': ['Margaretaskolan, Kv. Turkiet i Helsingborg.', 344, 346, 872, 'Foto', 'ur äldre samling'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/311502/1003_2002.jpg', 'itemMotiveWord': ['Turkiet', 'skola', 'Margaretaskolan', 'byggnad', 'folkskola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/249326', 'itemLabel': 'fotografi', 'itemDescription': [344, 'Foto', 'ur äldre samling', 872, 'Margaretaskolan, Kv. Turkiet i Helsingborg.', 346], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/311508/1004_2002.jpg', 'itemMotiveWord': ['Turkiet', 'folkskola', 'skola', 'byggnad', 'Margaretaskolan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/238039', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 367, 346, 'Slottshagen med Slottsvångsskolan i bakgrunden.'], 'create_fromTime': 1902, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/252297/00_288.jpg', 'itemMotiveWord': ['skola', 'landskap', 'park', 'Slottsvångsskolan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/835269', 'itemLabel': 'fotografi', 'itemDescription': [361, 367, 363, 344, 137, 'Svartvitt fotografi föreställande en utsikt från kärnan som visar bland annat Nicolaiskolan och barnsjukhuset.', 'Foto', 346], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/916050/349_2015.jpg', 'itemMotiveWord': ['Minerva', 'sjukhus', 'Bergaliden', 'skola', 'stadsbebyggelse', 'Nicolaiskolan', 'park', 'träd', 'Barnsjukhuset', 'arkitektur, i staden', 'väg']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/424068', 'itemLabel': 'fotografi', 'itemDescription': ['Foto', 322, 346, 'lånat och scannat', 'Nya skolan i Påarp slöjdsal'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/424071/DIG_2011_1306.jpg', 'itemMotiveWord': ['arkitektur, på landet', 'skola', 'träbearbetning']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/420831', 'itemLabel': 'vykort', 'itemDescription': ['Fleninge folkskola.', 'lånat och scannat', 'Foto', 346], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/423013/DIG_2011_1220.jpg', 'itemMotiveWord': ['arkitektur, på landet', 'skolelev', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/340526', 'itemLabel': 'fotografi, vykort', 'itemDescription': [346, 245, 'Vykort föreställande;  Mörarp - Folkskolan', 'Foto', '352 1', 'gåva'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/340529/2060_2005_009.jpg', 'itemMotiveWord': ['träd', 'trädgårdsmöbel', 'skola', 'Folkskolan i Mörarp', 'arkitektur, på landet']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/295887', 'itemLabel': 'fotografi', 'itemDescription': [346, 349, 342, 245, 'Fotografi, S. Petri Vattentorn och Slottsvångs skolan', 'Foto'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/295905/60_144.jpg', 'itemMotiveWord': ['Vattentornet', 'skola', 'vattentorn', 'Slottsvångsskolan', 'träd', 'arkitektur, i staden', 'bostadshus']}
# {'itemId': 'http://kulturarvsdata.se/HeM/fotografi/328141', 'itemLabel': 'fotografi', 'itemDescription': [87, 86, 'Foto', 'Skolelever i folkskolan för barn i Filborna och Västra Ramlösa. Barnen poserar i olika lekar, övervakade av läraren längst till vänster i bild.', 'Skolan låg i korsningen Hunnetorpsvägen - Vasatorpsvägen.'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/343408/91_519.jpg', 'itemMotiveWord': ['grupporträtt', 'skola', 'Filborna skola', 'skolklass', 'byggnad', 'skolundervisning']}
# ...
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/395272', 'itemLabel': 'interiörer', 'itemDescription': ['Foto', 'gåva', 'Med Helsingborg i sökaren, 2009-04-24--2010-03-28, Dunkers Kulturhus', 'Drottninghögsskolan', 'AB Helsingborgs-Bild', 'AB Helsingborgs-Bild'], 'create_fromTime': 1973, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/395275/78-2009_2.jpg', 'itemMotiveWord': ['skolelev', 'Drottninghög', 'skola', 'julförberedelse', 'skolsal', 'skolklass', 'interiörer']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/384318', 'itemLabel': 'grupporträtt', 'itemDescription': ['Lindberg Foto', 'Foto', 'Interner på Magnus Stenbocksskolan.', 'gåva'], 'create_fromTime': 1945, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/384321/4306-2008_2.jpg', 'itemMotiveWord': ['underhållning', 'grupporträtt', 'Magnus Stenbocksskolan', 'dans', 'krigsslut', 'skola', 'folkdräkt']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/384312', 'itemLabel': 'grupporträtt', 'itemDescription': ['Interner på Magnus Stenbocksskolan.', 'gåva', 'Foto', 'Lindberg Foto'], 'create_fromTime': 1945, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/384315/4306-2008_1.jpg', 'itemMotiveWord': ['underhållning', 'folkdräkt', 'skola', 'dans', 'grupporträtt', 'krigsslut']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/381765', 'itemLabel': 'scener, övriga', 'itemDescription': ['publicerad i Skånska Soicialdemokraten 28/8 1949', 'Lindberg Foto', 'Skolan börjar', 'gåva', '"Med Helsingborg i sökaren". 2013 sid 99', 'Foto', 'Med Helsingborg i sökaren, 2009-04-24--2010-03-28, Dunkers Kulturhus'], 'create_fromTime': 1949, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/381768/2091-2008_1.jpg', 'itemMotiveWord': ['skolelev', 'scener, övriga', 'gymnastiksal', 'Slottsvångsskolan', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/380024', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Praktiska mellanskolan, elever lär sig skriva maskin.', 'Foto', 'Lindberg Foto', 'gåva', 'Med Helsingborg i sökaren, 2009-04-24--2010-03-28, Dunkers Kulturhus'], 'create_fromTime': 1948, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/380027/2030-2008_3.jpg', 'itemMotiveWord': ['lärare', 'skrivmaskin', 'arkitektur, i staden', 'skola', 'skolelev', 'skolundervisning', 'skolsal']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/380012', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Lindberg Foto', 'Foto', 'Praktiska mellanskolan', 'gåva'], 'create_fromTime': 1948, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/380016/2030-2008_1.jpg', 'itemMotiveWord': ['skolrast', 'skolundervisning', 'arkitektur, i staden', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/541796', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Lindberg Foto', 'Skolgården på Slottvångsskolan.', 'Foto'], 'create_fromTime': 1964, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/541801/image.jpg', 'itemMotiveWord': ['bilparkering', 'Centrum', 'Slottsvångsskolan', 'skola', 'arkitektur, i staden']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1052507', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['AB Helsingborgs-Bild', 'Foto', 'Nybyggnationa på Rosengården.'], 'create_fromTime': 1978, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1052517/876-2016_3.jpg', 'itemMotiveWord': ['skola', 'byggnadsteknik', 'Rosengården', 'bostadsområde', 'arkitektur, i staden']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/380845', 'itemLabel': 'interiörer', 'itemDescription': ['Gossläroverket', 'Foto', 'gåva', 'Lindberg Foto'], 'create_fromTime': 1949, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/380848/2042-2008_1.jpg', 'itemMotiveWord': ['skola', 'interiörer', 'skolelev', 'skolmöbel', 'skolsal']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/380019', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Lindberg Foto', 'Med Helsingborg i sökaren, 2009-04-24--2010-03-28, Dunkers Kulturhus', 'gåva', 'Praktiska mellanskolan', 'Foto'], 'create_fromTime': 1948, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/380022/2030-2008_2.jpg', 'itemMotiveWord': ['skolelev', 'skola', 'arkitektur, i staden', 'lärare', 'skolundervisning', 'laboratorium', 'skolsal']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/403110', 'itemLabel': 'grupporträtt', 'itemDescription': ['gåva', 'Foto', 'Lindberg Foto', 'Skolpoliser på GA-skolan'], 'create_fromTime': 1955, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/403113/420-2009_2.jpg', 'itemMotiveWord': ['Zingjack, kerstin [fjärde från höger]', 'trafik', 'grupporträtt', 'skola', 'Högaborg', 'Gustav Adolfsskolan', 'Gustav Adolf', 'skolelev', 'examen']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/403101', 'itemLabel': 'grupporträtt', 'itemDescription': ['Foto', 'Lindberg Foto', 'Skolpoliser på GA-skolan', 'gåva'], 'create_fromTime': 1955, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/403107/420-2009_1.jpg', 'itemMotiveWord': ['skolelev', 'examen', 'Högaborg', 'grupporträtt', 'Gustav Adolfsskolan', 'trafik', 'Gustav Adolf', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1386555', 'itemLabel': 'interiörer', 'itemDescription': ['monterad', 'Svartvitt fotografi med motiv av en korridor på Högre allmänna läroverket för flickor, i Helsingborg. Korridoren är tom på människor. Längs ena väggen hänger ytterkläder på väggfasta klädhängare. Fotografiet är uppfodrat på kartong. Under fotografiet finns en handskriven text med information om byggnaden: "Korridor belagd med levanderplattor. / Högre Allmänna Läroverket för flickor, Hälsingborg. / Arkitekt: Stadsarkitekt Arvid Fuhre. Uppfört år 1933.".', 'Korridor belagd med levanderplattor. / Högre Allmänna Läroverket för flickor, Hälsingborg. / Arkitekt: Stadsarkitekt Arvid Fuhre. / Uppfört år 1933. [handskrivet framsida]', 'Foto'], 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1390605/34-80_e.jpg', 'itemMotiveWord': ['Olympiaskolan', 'Högre allmänna läroverket för flickor [äldre benämning]', 'interiörer', 'korridor', 'klädhängare', 'element', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/978866', 'itemLabel': 'grupporträtt', 'itemDescription': ['Foto', 'ASEA verstadsskola.', 'AB Helsingborgs-Bild'], 'create_fromTime': 1974, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/978878/1230-2015_2.jpg', 'itemMotiveWord': ['grupporträtt', 'skola', 'verkstadsindustri', 'Lussebäcken', 'svarvning']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1259737', 'itemLabel': 'grupporträtt', 'itemDescription': ['Foto', 'Grupp bild från Sundsgården.'], 'create_fromTime': 1950, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1259747/2937-2009_2.jpg', 'itemMotiveWord': ['skola', 'grupporträtt']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1259712', 'itemLabel': 'interiörer', 'itemDescription': ['Sundsgårdens folkhögskola.', 'Foto'], 'create_fromTime': 1958, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1259722/241-2012_3.jpg', 'itemMotiveWord': ['scen', 'interiörer', 'sal', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1259701', 'itemLabel': 'interiörer', 'itemDescription': ['Sundsgårdens folkhögskola.', 'Foto'], 'create_fromTime': 1958, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1259711/241-2012_2.jpg', 'itemMotiveWord': ['skola', 'sal', 'interiörer', 'scen']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/503385', 'itemLabel': 'interiörer', 'itemDescription': ['Lindberg Foto', 'Foto', 'Läroverkets aula'], 'create_fromTime': 1952, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/503395/image.jpg', 'itemMotiveWord': ['skolsal', 'skola', 'Nicolaiskolan', 'interiörer', 'sal', 'Centrum']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/653011', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Foto', 'Margaretaskolan rives', 'AB Helsingborgs-Bild [AB Helsingborgs-Bild]'], 'create_fromTime': 1957, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/653032/1136-2014_1.jpg', 'itemMotiveWord': ['skola', 'Söder', 'rivning', 'arkitektur, i staden', 'Margareta skolan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/480441', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Lindberg Foto', 'Wiselgrens skolan under byggnad', 'Foto'], 'create_fromTime': 1945, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/483001/image.jpg', 'itemMotiveWord': ['skola', 'arkitektur, i staden', 'bygge', 'Högaborg', 'Wieselgrensskolan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/401228', 'itemLabel': 'barnporträtt', 'itemDescription': ['Barnbespisning i Wieselgrensskolan', 'Lindberg Foto', 'Foto', 'gåva', 'Hallå! Helsingborg vecka 17, 2017-04-26-05-02'], 'create_fromTime': 1953, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/401231/343-2009_2.jpg', 'itemMotiveWord': ['matlagning', 'köksmaskin', 'Husensjö', 'kökspersonal', 'barnporträtt', 'Wieselgrensskolan', 'skola', 'kök']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1259690', 'itemLabel': 'arkitektur, på landet', 'itemDescription': ['Sundsgårdens folkhögskola.', 'Foto'], 'create_fromTime': 1958, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1259700/241-2012_1.jpg', 'itemMotiveWord': ['skola', 'arkitektur, på landet']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1058293', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Bilder tagna på uppdrag av Helsingborgshem, där de planerar ny bebyggelse.', 'AB Helsingborgs-Bild', 'Foto'], 'create_fromTime': 1980, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1058303/902-2016_9.jpg', 'itemMotiveWord': ['skola', 'Hantverkaregatan [troligen]', 'Söder [troligen]', 'bebyggelse', 'Tyskland', 'arkitektur, i staden']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1058124', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Foto', 'AB Helsingborgs-Bild', 'Bilder tagna på uppdrag av Helsingborgshem, där de planerar ny bebyggelse.'], 'create_fromTime': 1980, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1058135/902-2016_6.jpg', 'itemMotiveWord': ['skola', 'bebyggelse', 'arkitektur, i staden', 'Söder [troligen]', 'Hantverkaregatan [troligen]', 'Tyskland']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1057375', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Bilder tagna på uppdrag av Helsingborgshem, där de planerar ny bebyggelse. Tryckerigatan (f d Jaquardväveriet) med Fridhemsgatan omedelbart i bakgrunden.', 'Foto', 'AB Helsingborgs-Bild'], 'create_fromTime': 1980, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1057445/902-2016_4.jpg', 'itemMotiveWord': ['skola', 'bebyggelse', 'Fridhemsgatan', 'arkitektur, i staden', 'Tryckerigatan', 'Planteringen [troligen]', 'Helsingborgs Jacquardväfveri AB [f d]']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/541823', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Lindberg Foto', 'Foto', 'Skolgården på Slottvångsskolan.'], 'create_fromTime': 1964, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/541828/image.jpg', 'itemMotiveWord': ['Centrum', 'arkitektur, i staden', 'Slottsvångsskolan', 'bilparkering', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/424984', 'itemLabel': 'arkitektur, på landet', 'itemDescription': ['gåva', 'Wieselgrensskolans Nya Småskolebyggnad.', 'Lindberg Foto', 'Foto'], 'create_fromTime': 1952, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/424987/682-2010_1.jpg', 'itemMotiveWord': ['Wieselgrensskolan', 'bygge', 'skola', 'arkitektur, på landet', 'Husensjö', 'Ystadsgatan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/421295', 'itemLabel': 'kvinnoporträtt', 'itemDescription': ['Foto', 'gåva', 'Lärarina med elev.', 'Lindberg Foto'], 'create_fromTime': 1948, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/421298/6062-2008_6.jpg', 'itemMotiveWord': ['skolelev', 'kvinnoporträtt', 'skola', 'lärare']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/401052', 'itemLabel': 'kvinnoporträtt', 'itemDescription': ['gåva', 'Skinnknutteparad på Magnus Stenbocksskolan', 'Foto', 'Lindberg Foto'], 'create_fromTime': 1952, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/401055/330-2009_4.jpg', 'itemMotiveWord': ['Magnus Stenbocksskolan', 'skola', 'Tågaborg', 'motorcykel', 'klädsel', 'kvinnoporträtt']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/401040', 'itemLabel': 'grupporträtt', 'itemDescription': ['Skinnknutteparad på Magnus Stenbocksskolan', 'Lindberg Foto', 'gåva', 'Foto'], 'create_fromTime': 1952, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/401043/330-2009_1.jpg', 'itemMotiveWord': ['skola', 'motorcykel', 'grupporträtt', 'Tågaborg', 'Magnus Stenbocksskolan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/372434', 'itemLabel': 'grupporträtt', 'itemDescription': ['Med Helsingborg i sökaren, 2009-04-24--2010-03-28, Dunkers Kulturhus', '"Med Helsingborg i sökaren". 2013 sid 146', 'Foto', 'Skoldans på Gossis', 'AB Helsingborgs-Bild', 'gåva'], 'create_fromTime': 1957, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/372437/1136-2008_1.jpg', 'itemMotiveWord': ['orkester', 'byggnad', 'grupporträtt', 'piano', 'musiker', 'danslokal', 'musikinstrument', 'dans', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/502622', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Wiselgrensskolan', 'Foto', 'Lindberg Foto'], 'create_fromTime': 1950, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/502627/image.jpg', 'itemMotiveWord': ['Wieselgrensskolan', 'Facklan', 'skola', 'skolrast', 'arkitektur, i staden', 'undervisning', 'Högaborg', 'Ystadsgatan']}
# {'itemId': 'http://kulturarvsdata.se/HeM/delfotografi/1058208', 'itemLabel': 'arkitektur, i staden', 'itemDescription': ['Foto', 'Bilder tagna på uppdrag av Helsingborgshem, där de planerar ny bebyggelse.', 'AB Helsingborgs-Bild'], 'create_fromTime': 1980, 'thumbnail': 'https://museum.helsingborg.se/web/image/tn/1058222/902-2016_8.jpg', 'itemMotiveWord': ['bebyggelse', 'Tyskland', 'Hantverkaregatan [troligen]', 'arkitektur, i staden', 'Söder [troligen]', 'skola']}
# {'itemId': 'http://kulturarvsdata.se/SMVK-EM/fotografi/4315444', 'itemLabel': 'skola, folksamling, innergård, fotografi, photograph', 'itemDescription': ['Dubblett: 0964.a.2871, 0964.a.3137', 'Samling 0964 gåva från Equmeniakyrkans (tidigare Svenska Missionskyrkans) arkiv 2014.', 'Söndagsskola i det fria, Macheng.', '0964.a.1596'], 'thumbnail': 'https://collections.smvk.se/carlotta-em/web/image/tn/25243191/0964.a.1596.jpg', 'itemMotiveWord': ['innergård', 'crowd', 'skola', 'folksamling']}
# {'itemId': 'http://kulturarvsdata.se/SMVK-EM/fotografi/4317805', 'itemLabel': 'missionärer, skola, måltid, fotografi, photograph', 'itemDescription': ['Lidingö', 'Samling 0964 gåva från Equmeniakyrkans (tidigare Svenska Missionskyrkans) arkiv 2014.', 964.0583, 'Missionsskolan exp. SMF (nr 0964.0582 - 0590)'], 'thumbnail': 'https://collections.smvk.se/carlotta-em/web/image/tn/25155329/0964.0583_kopia.jpg', 'itemMotiveWord': ['måltid', 'skola', 'missionärer']}
# {'itemId': 'http://kulturarvsdata.se/SMVK-VKM/fotografi/1328514', 'itemLabel': 'fotografi, photograph', 'itemDescription': ['018293', 'Monica Zak i Karibiska havet', 'Mellanamerika', 'Skolflicka i San Blas. På bilden två flickor som skriver. Båda bär näsring och den ena ett halsband.', 'Centralamerika'], 'create_fromTime': 1969, 'thumbnail': 'https://collections.smvk.se/carlotta-vkm/web/image/tn/1328752/image.jpg', 'itemMotiveWord': ['Kuna', 'skola', 'sjal', 'undervisning']}

# %%
#dfTot
